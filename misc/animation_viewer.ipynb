# %% [markdown]
# # 3D Motion Visualization (Using Utils)
#
# This notebook uses the centralized visualization logic from `src/utils.py`.

# %%
import sys
import os
import numpy as np

# Add src directory to path
sys.path.append(os.path.abspath("../src"))
from utils.visualization import visualize_motion

# %%
# 1. Load data
data_path = "../sample_data/000000_joint.npy"
motion_data = np.load(data_path)

# 2. Visualize
visualize_motion(motion_data, title="Motion from 000000_joint.npy", fps=20, backend="matplotlib")

# %%
# 1. Load data
data_path = "../sample_data/000070_joint.npy"
motion_data = np.load(data_path)

# 2. Visualize
visualize_motion(motion_data, title="Motion from 000070_joint.npy", fps=20, backend="matplotlib")
